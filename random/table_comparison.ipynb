# %%
standardised_dev = ['legacy_timesheets_mwr_status',
 'timesheets_employee',
 'legacy_timesheets_mwr_lines',
 'timesheets_work_segment',
 'timesheets_segment_type_reference',
 'legacy_timesheets_mwr_inspector_dim',
 'timesheets_calendar',
 'legacy_timesheets_mwr_submission_date',
 'timesheets_work_segment_lock',
 'checkmark_case_comment',
 'checkmark_case_marking',
 'checkmark_comment_state_reference',
 'checkmark_comment_type_reference',
 'checkmark_complexity_reference',
 'checkmark_conditions_reference',
 'checkmark_coverage_reference',
 'checkmark_documents',
 'checkmark_grounds_reference',
 'checkmark_inspector_manager',
 'checkmark_invalid_nullity_reference',
 'checkmark_level_reference',
 'checkmark_manager_type_reference',
 'checkmark_nsi',
 'checkmark_outcome_reference',
 'checkmark_presentation_accuracy_detail_reference',
 'checkmark_procedure_reference',
 'checkmark_reading_case',
 'checkmark_reading_status_reference',
 'checkmark_reading_type_reference',
 'checkmark_source_reference',
 'checkmark_structure_reasoning_detail_reference',
 'horizon_add_additional_data',
 'horizon_advert_details',
 'horizon_all_appeals',
 'horizon_appeals_additional_data',
 'horizon_decision_issues',
 'horizon_enforcement_grounds_for_appeal',
 'horizon_lpa_responsibility',
 'horizon_special_circumstance',
 'horizon_specialism',
 'horizon_inspector_cases',
 'horizon_contacts_organisation',
 'checkmark_specialist_tpo',
 'checkmark_specialist_hh',
 'checkmark_local_plans',
 'checkmark_specialist_hedgerow',
 'horizon_nsip_redactions',
 'horizon_case_info',
 'horizon_case_officer_additional_details',
 'horizon_specialist_case_dates',
 'horizon_specialist_coastal_access',
 'horizon_specialist_environment',
 'horizon_specialist_recharge',
 'horizon_case_dates',
 'horizon_project_info_internal',
 'horizon_common_land',
 'horizon_specialist_high_court',
 'horizon_hzn_right_of_way',
 'horizon_event',
 'horizon_additional_fields',
 'horizon_app_sub_type_case_name',
 'horizon_specialist_purchase_notice',
 'horizon_specialist_case_string',
 'casework_local_plans',
 'casework_picaso',
 'horizon_local_planning_authority',
 'horizon_specialist_modifications',
 'casework_specialist_tpo',
 'casework_specialist_hedgerow',
 'casework_specialist_hh',
 'zendesk_output_0',
 'zendesk_tags',
 'abdullah_test',
 'ims_attribute',
 'ims_dpia',
 'ims_dataflow',
 'ims_dsa',
 'ims_entity',
 'ims_informationasset',
 'ims_intergration',
 'ims_masterdatamap',
 'ims_ropa',
 'hr_addresses',
 'sap_hr_historic',
 'hr_saphr',
 'hr_protected_characteristics',
 'hr_work_schedule_rule',
 'hr_absences',
 'hr_specialisms',
 'hr_email',
 'hr_leave',
 'hr_leavers',
 'bis_pension_ernic_rates',
 'vw_addresses_temp',
 'zendesk_system_extract',
 'ims_ropa_new_data',
 'ims_attribute_new',
 'ims_entity_new',
 'ims_dataflow_new',
 'ims_dsa_new',
 'ims_dpia_new',
 'ims_informationasset_new',
 'ims_intergration_new',
 'ims_masterdatamap_new',
 'ims_ropa_new',
 'high_court',
 'horizon_bis_event',
 'listed_building_outline',
 'listed_building',
 'zendesk_legacy',
 'vw_all_appeals',
 'vw_all_additional_appeal',
 'vw_hedgerow',
 'vw_high_hedge',
 'horizon_contact_information',
 'document_document_tree',
 'document_case_reference',
 'document_case_type',
 'horizon_service_user',
 'vw_absences_temp',
 'vw_absences',
 'hr_addresses_temp',
 'vw_addresses',
 'hr_email_temp',
 'vw_email',
 'vw_leave',
 'vw_leavers_temp',
 'vw_leavers',
 'vw_protected_characteristics',
 'vw_saphr',
 'vw_specialisms',
 'nsip_document',
 'horizon_nsip_data',
 'nsip_project',
 'nsip_project_update',
 'horizon_nsip_relevant_representation',
 'service_user',
 'nsip_subscription',
 'nsip_representation',
 'document_meta_data',
 'aie_document_data',
 'horizon_case_involvement',
 'horizon_folder',
 'folder',
 'zendesk_new_tickets',
 'zendesk_updated_tickets',
 'zendesk_created_tickets',
 'sample_table_with_arrays',
 'horizon_examination_timetable',
 'horizon_appeals_folder',
 'horizon_appeals_document_metadata',
 'appeal_document',
 'horizon_appeals_event',
 'appeals_event',
 'sb_appeal_document',
 'sb_appeal_event',
 'nsip_exam_timetable',
 'sb_entra_id',
 'nsip_s51_advice',
 'casework_nsip_advice_dim',
 'sb_nsip_representation_iterate',
 'entraid',
 'horizon_nsip_advice',
 'sb_appeal_has',
 'sb_appeal_has_temp',
 'sb_nsip_project',
 'sb_nsip_project_tmp',
 'sb_nsip_representation',
 'sb_nsip_representation_tmp',
 'sb_s51_advice',
 'sb_s51_advice_tmp',
 'horizon_s62a_view_case_dates',
 'horizon_s62a_view_case_extended_data',
 'horizon_s62a_view_case_officers',
 'horizon_s62a_view_cases',
 'horizon_s62a_view_case_basic_data']

harmonised_dev = ['legacy_mwr_inspector_join',
 'legacy_mwr_lines_dim',
 'legacy_mwr_record_fact',
 'legacy_mwr_status_dim',
 'legacy_mwr_submission_date_dim',
 'checkmark_complexity_reference_dim',
 'checkmark_conditions_reference_dim',
 'checkmark_grounds_reference_dim',
 'checkmark_level_reference_dim',
 'checkmark_manager_type_reference_dim',
 'checkmark_nsi_dim',
 'checkmark_outcome_reference_dim',
 'checkmark_presentation_accuracy_detail_reference_dim',
 'checkmark_procedure_reference_dim',
 'checkmark_reading_status_reference_dim',
 'checkmark_reading_type_reference_dim',
 'checkmark_source_reference_dim',
 'checkmark_structure_reasoning_detail_reference_dim',
 'checkmark_comment_state_reference_dim',
 'checkmark_comment_type_reference_dim',
 'checkmark_documents_dim',
 'checkmark_invalid_nullity_reference_dim',
 'checkmark_casemarking_dim',
 'checkmark_inspector_manager_dim',
 'checkmark_reading_case_dim',
 'checkmark_comments_dim',
 'checkmark_coverage_reference_dim',
 'checkmark_case_fact',
 'checkmark_case_casemarking_bridge',
 'timesheets_record_fact',
 'checkmark_casemarking_fact',
 'checkmark_comments_case_bridge',
 'checkmark_comments_fact',
 'casework_application_sub_type_case_name_dim',
 'checkmark_case_reading_case_bridge',
 'checkmark_inspector_manager_fact',
 'checkmark_inspector_manager_reading_case_bridge',
 'checkmark_reading_case_fact',
 'date_dim',
 'hr_employee_fact',
 'hr_employee_hr_hierarchy_dim',
 'hr_contract_dim',
 'hr_diversity_dim',
 'hr_costcenter_dim',
 'hr_absence_dim',
 'hr_employeegroup_dim',
 'hr_disability_dim',
 'hr_pins_location_dim',
 'hr_position_dim',
 'hr_organisation_unit_dim',
 'hr_personnel_area_dim',
 'hr_record_fact',
 'hr_leave_entitlement_dim',
 'hr_personnel_sub_area_dim',
 'hr_payband_dim',
 'hr_religion_dim',
 'hr_payroll_area_dim',
 'hr_specialism_dim',
 'main_sourcesystem_fact',
 'hr_secure_info_fact',
 'hr_sxo_dim',
 'hr_work_schedule_dim',
 'hr_employee_dim',
 'zendesk_fields_id_value',
 'zendesk_custom_fields_id_value',
 'high_court_dim',
 'zendesk_comments',
 'zendesk_comments_attachments',
 'zendesk_assignee',
 'zendesk_submitter',
 'zendesk_requester',
 'zendesk_collaborator',
 'ims_integration_dim',
 'ims_ropa_dim',
 'ims_dataflow_dim',
 'ims_attribute_dim',
 'ims_entity_dim',
 'ims_information_asset_dim',
 'ims_masterdata_map_dim',
 'ims_dpia_dim',
 'ims_dsa_dim',
 'listed_building_dim',
 'listed_building_outline_dim',
 'timesheets_minutes_dim',
 'timesheets_segment_type_reference_dim',
 'timesheets_work_segment_dim',
 'timesheets_work_segment_lock_dim',
 'hr_employee_leavers_dim',
 'casework_case_info_dim',
 'casework_case_fact',
 'casework_case_officer_additional_details_dim',
 'casework_common_land_dim',
 'casework_case_dates_dim',
 'casework_all_appeals_dim',
 'casework_all_appeals_additional_data_dim',
 'casework_additional_fields_dim',
 'casework_advert_details_dim',
 'casework_event_fact',
 'casework_hedgerow_dim',
 'casework_inspector_cases_dim',
 'casework_high_hedges_dim',
 'casework_legacy_rights_of_way_dim',
 'casework_event_dim',
 'casework_enforcement_grounds_dim',
 'casework_decision_issue_dim',
 'casework_contacts_organisation_dim',
 'casework_picaso_dim',
 'casework_nsip_redactions_dim',
 'casework_lpa_responsibility_dim',
 'casework_local_planning_authority_dim',
 'casework_local_plans_dim',
 'casework_local_planning_authority_fact',
 'casework_specialism_dim',
 'casework_specialist_coastal_access_dim',
 'casework_specialist_case_string_dim',
 'casework_specialist_environment_dim',
 'casework_specialist_high_court_dim',
 'casework_specialist_case_dates_dim',
 'casework_special_circumstance_dim',
 'casework_specialist_recharge_dim',
 'casework_specialist_modifications_dim',
 'casework_specialist_purchase_notice_dim',
 'casework_tpo_dim',
 'casework_contact_information_dim',
 'ims',
 'casework_examination_timetable_dim',
 'casework_picasso_dim',
 'hr_historic_sap_hr',
 'casework_nsip_project_info_internal_dim',
 'document_case_reference_dim',
 'document_tree_dim',
 'document_case_type_dim',
 'casework_nsip_advice_dim_temp',
 'casework_nsip_service_user_dim',
 'casework_nsip_data_dim',
 'casework_case_involvement_dim',
 'casework_nsip_relevant_representation_dim',
 'casework_nsip_advice_dim',
 'nsip_subscription',
 'horizon_folder',
 'document_meta_data_backup',
 'document_meta_data',
 'casework_nsip_examination_timetable_dim',
 'horizon_appeals_folder',
 'appeals_folder',
 'sb_appeal_document',
 'appeals_document_metadata',
 'aie_document_data',
 'horizon_appeals_event',
 'nsip_project',
 'entraid',
 'folder',
 'sb_appeal_event',
 'nsip_document',
 'nsip_representation',
 'sb_nsip_representation',
 'nsip_relevant_representation',
 'nsip_project_update',
 'service_user',
 'sb_nsip_project',
 'vw_appeals_event_unified',
 'sb_s51_advice',
 'sb_appeal_has',
 'nsip_s51_advice',
 's62a_view_case_basic_data_dim',
 's62a_view_case_dates_dim',
 's62a_view_case_extended_data_dim',
 's62a_view_case_officers_dim',
 's62a_view_cases_dim']

curated_dev = ['vw_mipins_employee_summary',
 'vw_mipins_hr_gender',
 'nsip_relevant_reps',
 'mipins_hr_measures',
 'employee',
 'vw_mipins_hr_personnel_area',
 'vw_mipins_hr_contract',
 'mipins_hr_personnel_area',
 'vw_mipins_hr_cost_centre',
 'mipins_hr_contract',
 'vw_mipins_hr_organisational_unit',
 'mipins_hr_cost_centre',
 'mipins_hr_organisational_unit',
 'vw_mipins_hr_personnel_sub_area',
 'mipins_hr_personnel_sub_area',
 'vw_mipins_hr_protected_data',
 'vw_mipins_ims_masterdatamap',
 'vw_mipins_hr_employee_leavers',
 'mipins_hr_employee_leavers',
 'vw_mipins_fact_absence_all',
 'mipins_fact_absence_all',
 'vw_mipins_high_court',
 'mipins_high_court',
 'service_user',
 'vw_nsip_s51_advice1',
 'test_table',
 'nsip_s51_advice_test',
 'nsip_s51_advice_test1',
 'vw_nsip_s51_advice_test',
 'vw_mipins_hr_fact_sickness_union',
 'vw_mipins_hr_fact_sickness',
 'mipins_hr_fact_sickness',
 'nsip_service_user',
 'vw_nsip_project_update',
 'nsip_project_update',
 'nsip_project_ct_test',
 'vw_dart_cases_api',
 'dart_cases_api',
 'appeal_document',
 'vw_appeals_document_metadata',
 'appeals_document_metadata',
 'vw_appeals_folder_curated',
 'appeals_folder_curated',
 'sb_appeal_document',
 'sb_appeal_event',
 'appeal_event',
 'vw_appeal_has',
 'nsip_representation',
 'vw_sb_appeal_has',
 'sb_appeal_has',
 'nsip_data',
 's51_advice',
 'appeals_event',
 'vw_nsip_s51_advice',
 'nsip_s51_advice',
 'vw_examination_timetable',
 'examination_timetable',
 'vw_document_metadata',
 'vw_service_user',
 'document_meta_data',
 'vw_legacy_folder_data',
 'vw_nsip_subscription',
 'legacy_folder_data',
 'nsip_subscription',
 'vw_nsip_data',
 'vw_nsip_service_user',
 'vw_relevant_representation',
 'relevant_representation',
 'vw_sb_appeal_has_powerbi',
 'sb_appeal_has_powerbi']

standardised_test = ['checkmark_case_comment',
 'checkmark_case_marking',
 'checkmark_comment_state_reference',
 'checkmark_comment_type_reference',
 'checkmark_complexity_reference',
 'checkmark_conditions_reference',
 'checkmark_coverage_reference',
 'checkmark_documents',
 'checkmark_grounds_reference',
 'checkmark_inspector_manager',
 'checkmark_invalid_nullity_reference',
 'checkmark_level_reference',
 'checkmark_manager_type_reference',
 'checkmark_nsi',
 'checkmark_outcome_reference',
 'checkmark_presentation_accuracy_detail_reference',
 'checkmark_procedure_reference',
 'checkmark_reading_case',
 'checkmark_reading_status_reference',
 'checkmark_reading_type_reference',
 'checkmark_source_reference',
 'checkmark_structure_reasoning_detail_reference',
 'horizon_add_additional_data',
 'horizon_advert_details',
 'horizon_all_appeals',
 'horizon_appeals_additional_data',
 'horizon_decision_issues',
 'horizon_enforcement_grounds_for_appeal',
 'horizon_lpa_responsibility',
 'horizon_special_circumstance',
 'horizon_specialism',
 'legacy_timesheets_mwr_lines',
 'legacy_timesheets_mwr_status',
 'legacy_timesheets_mwr_submission_date',
 'timesheets_calendar',
 'timesheets_employee',
 'timesheets_segment_type_reference',
 'timesheets_work_segment',
 'timesheets_work_segment_lock',
 'legacy_timesheets_mwr_inspector_dim',
 'horizon_inspector_cases',
 'horizon_contacts_organisation',
 'casework_local_plans',
 'horizon_additional_fields',
 'horizon_app_sub_type_case_name',
 'horizon_case_dates',
 'horizon_case_info',
 'horizon_case_officer_additional_details',
 'horizon_common_land',
 'horizon_event',
 'horizon_hzn_right_of_way',
 'horizon_nsip_redactions',
 'horizon_project_info_internal',
 'horizon_specialist_case_dates',
 'horizon_specialist_case_string',
 'horizon_specialist_coastal_access',
 'horizon_specialist_environment',
 'horizon_specialist_high_court',
 'horizon_specialist_modifications',
 'horizon_specialist_purchase_notice',
 'horizon_specialist_recharge',
 'casework_picaso',
 'horizon_local_planning_authority',
 'horizon_contact_information',
 'hr_specialisms',
 'hr_protected_characteristics',
 'hr_addresses',
 'hr_leave',
 'hr_absences',
 'hr_work_schedule_rule',
 'hr_leavers',
 'hr_saphr',
 'hr_email',
 'sap_hr_historic',
 'bis_pension_ernic_rates',
 'ims_attribute',
 'high_court',
 'casework_specialist_hedgerow',
 'casework_specialist_hh',
 'casework_specialist_tpo',
 'horizon_bis_event',
 'vw_all_appeals',
 'vw_all_additional_appeal',
 'vw_hedgerow',
 'vw_high_hedge',
 'listed_building',
 'listed_building_outline',
 'horizon_service_user_new',
 'vw_absences_temp',
 'vw_absences',
 'hr_addresses_temp',
 'vw_addresses',
 'hr_email_temp',
 'vw_email',
 'vw_leave',
 'vw_leavers_temp',
 'vw_leavers',
 'vw_protected_characteristics',
 'vw_saphr',
 'vw_specialisms',
 'nsip_document',
 'horizon_examination_timetable',
 'horizon_nsip_advice',
 'horizon_nsip_relevant_representation',
 'horizon_folder',
 'document_meta_data',
 'horizon_nsip_data',
 'aie_document_data',
 'nsip_s51_advice',
 'nsip_project_update',
 'nsip_subscription',
 'nsip_representation',
 'folder',
 'nsip_project',
 'service_user',
 'nsip_exam_timetable']

harmonised_test = ['casework_application_sub_type_case_name_dim',
 'casework_examination_timetable_dim',
 'casework_picasso_dim',
 'checkmark_case_casemarking_bridge',
 'checkmark_case_fact',
 'checkmark_case_reading_case_bridge',
 'checkmark_casemarking_dim',
 'checkmark_casemarking_fact',
 'checkmark_comment_state_reference_dim',
 'checkmark_comment_type_reference_dim',
 'checkmark_comments_case_bridge',
 'checkmark_comments_dim',
 'checkmark_comments_fact',
 'checkmark_complexity_reference_dim',
 'checkmark_conditions_reference_dim',
 'checkmark_coverage_reference_dim',
 'checkmark_documents_dim',
 'checkmark_grounds_reference_dim',
 'checkmark_inspector_manager_dim',
 'checkmark_inspector_manager_fact',
 'checkmark_inspector_manager_reading_case_bridge',
 'checkmark_invalid_nullity_reference_dim',
 'checkmark_level_reference_dim',
 'checkmark_manager_type_reference_dim',
 'checkmark_nsi_dim',
 'checkmark_outcome_reference_dim',
 'checkmark_presentation_accuracy_detail_reference_dim',
 'checkmark_procedure_reference_dim',
 'checkmark_reading_case_dim',
 'checkmark_reading_case_fact',
 'checkmark_source_reference_dim',
 'checkmark_structure_reasoning_detail_reference_dim',
 'date_dim',
 'legacy_mwr_inspector_join',
 'legacy_mwr_lines_dim',
 'legacy_mwr_record_fact',
 'legacy_mwr_status_dim',
 'legacy_mwr_submission_date_dim',
 'timesheets_minutes_dim',
 'timesheets_record_fact',
 'timesheets_segment_type_reference_dim',
 'timesheets_work_segment_dim',
 'timesheets_work_segment_lock_dim',
 'hr_historic_sap_hr',
 'hr_contract_dim',
 'hr_costcenter_dim',
 'hr_disability_dim',
 'hr_diversity_dim',
 'hr_employee_dim',
 'hr_employee_hr_hierarchy_dim',
 'hr_absence_dim',
 'hr_employee_fact',
 'hr_employeegroup_dim',
 'hr_organisation_unit_dim',
 'hr_payband_dim',
 'hr_payroll_area_dim',
 'hr_personnel_area_dim',
 'hr_personnel_sub_area_dim',
 'hr_record_fact',
 'hr_pins_location_dim',
 'hr_position_dim',
 'hr_leave_entitlement_dim',
 'hr_religion_dim',
 'hr_specialism_dim',
 'hr_sxo_dim',
 'hr_work_schedule_dim',
 'main_sourcesystem_fact',
 'hr_secure_info_fact',
 'high_court_dim',
 'casework_case_officer_additional_details_dim',
 'casework_case_fact',
 'casework_all_appeals_dim',
 'casework_case_info_dim',
 'casework_additional_fields_dim',
 'casework_advert_details_dim',
 'casework_case_dates_dim',
 'casework_all_appeals_additional_data_dim',
 'casework_common_land_dim',
 'casework_high_hedges_dim',
 'casework_inspector_cases_dim',
 'casework_event_fact',
 'casework_decision_issue_dim',
 'casework_contact_information_dim',
 'casework_hedgerow_dim',
 'casework_contacts_organisation_dim',
 'casework_event_dim',
 'casework_enforcement_grounds_dim',
 'casework_legacy_rights_of_way_dim',
 'casework_nsip_redactions_dim',
 'casework_local_planning_authority_dim',
 'casework_local_plans_dim',
 'casework_local_planning_authority_fact',
 'casework_nsip_project_info_internal_dim',
 'casework_lpa_responsibility_dim',
 'casework_picaso_dim',
 'casework_specialist_case_string_dim',
 'casework_specialist_recharge_dim',
 'casework_specialist_environment_dim',
 'casework_specialist_modifications_dim',
 'casework_specialism_dim',
 'casework_specialist_purchase_notice_dim',
 'casework_specialist_case_dates_dim',
 'casework_special_circumstance_dim',
 'casework_specialist_coastal_access_dim',
 'casework_specialist_high_court_dim',
 'casework_tpo_dim',
 'hr_employee_leavers_dim',
 'service_user_dim',
 'service_user',
 'nsip_document',
 'casework_nsip_examination_timetable_dim',
 'document_meta_data',
 'casework_nsip_advice_dim',
 'horizon_folder',
 'casework_nsip_relevant_representation_dim',
 'casework_nsip_data_dim',
 'aie_document_data',
 'casework_case_involvement_dim',
 'nsip_project_update',
 'nsip_subscription',
 'nsip_representation',
 'folder']

curated_test = ['mipins_hr_measures',
 'employee',
 'vw_mipins_fact_absence_all',
 'vw_mipins_hr_cost_centre',
 'mipins_hr_cost_centre',
 'vw_mipins_hr_organisational_unit',
 'vw_mipins_hr_contract',
 'mipins_hr_organisational_unit',
 'mipins_hr_contract',
 'vw_mipins_hr_personnel_area',
 'mipins_hr_personnel_area',
 'vw_mipins_hr_personnel_sub_area',
 'mipins_hr_personnel_sub_area',
 'vw_mipins_hr_employee_leavers',
 'vw_mipins_hr_protected_data',
 'mipins_hr_employee_leavers',
 'mipins_hr_protected_data',
 'mipins_fact_absence_all',
 'vw_mipins_high_court',
 'mipins_high_court',
 'vw_mipins_hr_fact_sickness_union',
 'vw_mipins_hr_fact_sickness',
 'mipins_hr_fact_sickness',
 'service_user',
 'vw_service_user',
 'nsip_data',
 'nsip_service_user',
 'vw_nsip_subscription',
 'nsip_subscription',
 'vw_examination_timetable',
 'examination_timetable',
 'vw_nsip_s51_advice',
 'nsip_s51_advice',
 'vw_nsip_project_update',
 'vw_legacy_folder_data',
 'legacy_folder_data',
 'nsip_project_update',
 'vw_nsip_data',
 'vw_nsip_service_user',
 'vw_relevant_representation',
 'relevant_representation',
 'vw_document_metadata',
 'document_meta_data']

# %%
in_dev_not_in_test = sorted(list(set(standardised_dev) - set(standardised_test)))
print(len(in_dev_not_in_test))
in_dev_not_in_test
# Out:
# 61
# ['abdullah_test',
#  'appeal_document',
#  'appeals_event',
#  'casework_nsip_advice_dim',
#  'checkmark_local_plans',
#  'checkmark_specialist_hedgerow',
#  'checkmark_specialist_hh',
#  'checkmark_specialist_tpo',
#  'document_case_reference',
#  'document_case_type',
#  'document_document_tree',
#  'entraid',
#  'horizon_appeals_document_metadata',
#  'horizon_appeals_event',
#  'horizon_appeals_folder',
#  'horizon_case_involvement',
#  'horizon_s62a_view_case_basic_data',
#  'horizon_s62a_view_case_dates',
#  'horizon_s62a_view_case_extended_data',
#  'horizon_s62a_view_case_officers',
#  'horizon_s62a_view_cases',
#  'horizon_service_user',
#  'ims_attribute_new',
#  'ims_dataflow',
#  'ims_dataflow_new',
#  'ims_dpia',
#  'ims_dpia_new',
#  'ims_dsa',
#  'ims_dsa_new',
#  'ims_entity',
#  'ims_entity_new',
#  'ims_informationasset',
#  'ims_informationasset_new',
#  'ims_intergration',
#  'ims_intergration_new',
#  'ims_masterdatamap',
#  'ims_masterdatamap_new',
# ...
