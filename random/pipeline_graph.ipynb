# %%
import json

# %%
# Sample JSON data representing a pipeline
pipeline_data = {
    "name": "pln_applications_master",
    "properties": {
        "description": "Master ingestion pipeline for applications",
        "activities": [
            {
                "name": "pln_service_bus_nsip_project_update",
                "type": "ExecutePipeline",
                "dependsOn": [],
                "userProperties": [],
                "typeProperties": {
                    "pipeline": {
                        "referenceName": "pln_service_bus_nsip_project_update",
                        "type": "PipelineReference"
                    },
                    "waitOnCompletion": "true"
                }
            },
            {
                "name": "pln_horizon_nsip_representation_main",
                "type": "ExecutePipeline",
                "dependsOn": [],
                "userProperties": [],
                "typeProperties": {
                    "pipeline": {
                        "referenceName": "pln_horizon_nsip_representation_main",
                        "type": "PipelineReference"
                    },
                    "waitOnCompletion": "true"
                }
            },
            {
                "name": "pln_nsip_exam_timetable_main",
                "type": "ExecutePipeline",
                "dependsOn": [],
                "userProperties": [],
                "typeProperties": {
                    "pipeline": {
                        "referenceName": "pln_nsip_exam_timetable_main",
                        "type": "PipelineReference"
                    },
                    "waitOnCompletion": "true"
                }
            },
            {
                "name": "pln_nsip_project_main",
                "type": "ExecutePipeline",
                "dependsOn": [],
                "userProperties": [],
                "typeProperties": {
                    "pipeline": {
                        "referenceName": "pln_nsip_project_main",
                        "type": "PipelineReference"
                    },
                    "waitOnCompletion": "true"
                }
            },
            {
                "name": "pln_service_user_main",
                "type": "ExecutePipeline",
                "dependsOn": [
                    {
                        "activity": "pln_horizon_nsip_representation_main",
                        "dependencyConditions": [
                            "Succeeded"
                        ]
                    },
                    {
                        "activity": "pln_nsip_project_main",
                        "dependencyConditions": [
                            "Succeeded"
                        ]
                    }
                ],
                "userProperties": [],
                "typeProperties": {
                    "pipeline": {
                        "referenceName": "pln_service_user_main",
                        "type": "PipelineReference"
                    },
                    "waitOnCompletion": "true"
                }
            },
            {
                "name": "pln_service_bus_nsip_subscription",
                "type": "ExecutePipeline",
                "dependsOn": [],
                "userProperties": [],
                "typeProperties": {
                    "pipeline": {
                        "referenceName": "pln_service_bus_nsip_subscription",
                        "type": "PipelineReference"
                    },
                    "waitOnCompletion": "true"
                }
            },
            {
                "name": "pln_nsip_s51_advice_main",
                "type": "ExecutePipeline",
                "dependsOn": [],
                "userProperties": [],
                "typeProperties": {
                    "pipeline": {
                        "referenceName": "pln_nsip_s51_advice_main",
                        "type": "PipelineReference"
                    },
                    "waitOnCompletion": "true"
                }
            }
        ],
        "folder": {
            "name": "utils"
        },
        "annotations": []
    }
}

# Function to generate Mermaid syntax from pipeline data
def generate_mermaid_syntax(pipeline_data):
    mermaid_code = "graph TD;\n"
    for activity in pipeline_data['properties']["activities"]:
        mermaid_code += f'    {activity["name"]}["{activity["name"]}"];\n'
        if activity["dependsOn"]:
            for dependency in activity["dependsOn"]:
                mermaid_code += f'    {dependency} -->|Dependency| {activity};\n'
    return mermaid_code

# Generate Mermaid syntax
mermaid_syntax = generate_mermaid_syntax(pipeline_data)
print(mermaid_syntax)  # Output the generated Mermaid code
# Out:
# graph TD;
#     pln_service_bus_nsip_project_update["pln_service_bus_nsip_project_update"];
#     pln_horizon_nsip_representation_main["pln_horizon_nsip_representation_main"];
#     pln_nsip_exam_timetable_main["pln_nsip_exam_timetable_main"];
#     pln_nsip_project_main["pln_nsip_project_main"];
#     pln_service_user_main["pln_service_user_main"];
#     {'activity': 'pln_horizon_nsip_representation_main', 'dependencyConditions': ['Succeeded']} -->|Dependency| {'name': 'pln_service_user_main', 'type': 'ExecutePipeline', 'dependsOn': [{'activity': 'pln_horizon_nsip_representation_main', 'dependencyConditions': ['Succeeded']}, {'activity': 'pln_nsip_project_main', 'dependencyConditions': ['Succeeded']}], 'userProperties': [], 'typeProperties': {'pipeline': {'referenceName': 'pln_service_user_main', 'type': 'PipelineReference'}, 'waitOnCompletion': 'true'}};
#     {'activity': 'pln_nsip_project_main', 'dependencyConditions': ['Succeeded']} -->|Dependency| {'name': 'pln_service_user_main', 'type': 'ExecutePipeline', 'dependsOn': [{'activity': 'pln_horizon_nsip_representation_main', 'dependencyConditions': ['Succeeded']}, {'activity': 'pln_nsip_project_main', 'dependencyConditions': ['Succeeded']}], 'userProperties': [], 'typeProperties': {'pipeline': {'referenceName': 'pln_service_user_main', 'type': 'PipelineReference'}, 'waitOnCompletion': 'true'}};
#     pln_service_bus_nsip_subscription["pln_service_bus_nsip_subscription"];
#     pln_nsip_s51_advice_main["pln_nsip_s51_advice_main"];
